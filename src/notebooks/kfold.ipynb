# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

path = '../input/siim-isic-melanoma-classification/'
data = pd.read_csv(path + 'train.csv')

# %%
# Out:
#          image_name  patient_id     sex  age_approx  \
# 0      ISIC_2637011  IP_7279968    male        45.0
# 1      ISIC_0015719  IP_3075186  female        45.0
# 2      ISIC_0052212  IP_2842074  female        50.0
# 3      ISIC_0068279  IP_6890425  female        45.0
# 4      ISIC_0074268  IP_8723313  female        55.0
# ...             ...         ...     ...         ...
# 33121  ISIC_9999134  IP_6526534    male        50.0
# 33122  ISIC_9999320  IP_3650745    male        65.0
# 33123  ISIC_9999515  IP_2026598    male        20.0
# 33124  ISIC_9999666  IP_7702038    male        50.0
# 33125  ISIC_9999806  IP_0046310    male        45.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target
# 0                         head/neck   unknown           benign       0
# 1                   upper extremity   unknown           benign       0
# 2                   lower extremity     nevus           benign       0
# ...

# %%
data.diagnosis.unique()
# Out:
# array(['unknown', 'nevus', 'melanoma', 'seborrheic keratosis',
#        'lentigo NOS', 'lichenoid keratosis', 'solar lentigo',
#        'cafe-au-lait macule', 'atypical melanocytic proliferation'],
#       dtype=object)

# %%
data[data.patient_id == 'IP_3232631']
# Out:
#          image_name  patient_id     sex  age_approx  \
# 459    ISIC_0247330  IP_3232631  female        65.0
# 2504   ISIC_0849702  IP_3232631  female        65.0
# 5387   ISIC_1710179  IP_3232631  female        65.0
# 9338   ISIC_2898780  IP_3232631  female        65.0
# 12599  ISIC_3880459  IP_3232631  female        65.0
# 13492  ISIC_4140008  IP_3232631  female        65.0
# 14087  ISIC_4322822  IP_3232631  female        65.0
# 15097  ISIC_4622069  IP_3232631  female        65.0
# 15894  ISIC_4863236  IP_3232631  female        65.0
# 16007  ISIC_4897852  IP_3232631  female        65.0
# 16435  ISIC_5030416  IP_3232631  female        65.0
# 18915  ISIC_5739570  IP_3232631  female        65.0
# 19625  ISIC_5960641  IP_3232631  female        65.0
# 21396  ISIC_6490895  IP_3232631  female        65.0
# 24364  ISIC_7394897  IP_3232631  female        65.0
# 26909  ISIC_8155634  IP_3232631  female        65.0
# 26915  ISIC_8157303  IP_3232631  female        65.0
# ...

# %%
t
# Out:
# [2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  4,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  3,
#  5,
#  3,
#  3,
#  1,
#  2,
#  3,
#  3,
#  2,
#  2,
#  3,
#  5,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  2,
#  1,
#  2,
#  3,
#  1,
#  5,
#  1,
#  1,
#  1,
#  8,
#  2,
#  1,
#  1,
#  2,
#  1,
#  3,
#  1,
#  2,
#  2,
#  2,
#  3,
#  1,
#  3,
#  1,
#  2,
#  1,
#  1,
#  5,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  3,
#  8,
#  1,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  4,
#  1,
#  1,
#  1,
#  2,
#  1,
#  4,
#  5,
#  1,
#  8,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  2,
#  3,
#  2,
#  1,
#  8,
#  2,
#  1,
#  1,
#  1,
#  3,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
#  3,
#  1,
#  2,
#  1,
#  2,
#  1,
#  3,
#  1,
#  1,
#  3,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  1,
#  6,
#  1,
#  3,
#  1,
#  2,
#  3,
#  6,
#  1,
#  1,
#  3,
#  1,
#  1,
#  2,
#  3,
#  1,
#  1,
#  2,
#  3,
#  1,
# ...

# %%
t = []
for pid in data[data.target == 1].patient_id:
    t.append(data[data.patient_id == pid].target.sum())

    
plt.hist(t, bins=8)
# Out:
# (array([319., 158.,  63.,  20.,  10.,   6.,   0.,   8.]),
#  array([1.   , 1.875, 2.75 , 3.625, 4.5  , 5.375, 6.25 , 7.125, 8.   ]),
#  <a list of 8 Patch objects>)

# %%
#              pred    site    age    target = target             
# patient 1
# patient 2
# patient 3 


class StratifiedGroupShuffleSplit:
    
    def __init__(self, n_splits=5):
        self.n_splits = n_splits
        
    def split(self, X, y, groups):
